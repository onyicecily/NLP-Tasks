# %%
import requests
from bs4 import BeautifulSoup
from gensim.summarization import summarize

# %%
url = 'https://www.npr.org/2021/04/28/991683886/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause'

# %%
page = requests.get(url).text

# %%
soup = BeautifulSoup(page)

# %%
header = soup.find('h1').text

# %%
date = soup.find('span', attrs={'class':'date'}).text

# %%
p_tags = soup.find_all('p')
p_tags
# Out:
# [<p class="byline__name byline__name--block">
#  <a data-metrics='{"action":"Click Byline","category":"Story Metadata"}' href="https://www.npr.org/people/2101289/nina-totenberg" rel="author">
#        Nina Totenberg
#      </a>
#  </p>,
#  <p>
#                  Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.
#
#                  <b aria-label="Image credit" class="credit">
#
#                      Danna Singer/ACLU/AP
#
#                  </b>
#  <b class="hide-caption"><b>hide caption</b></b>
#  </p>,
#  <p class="caption">Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.</p>,
#  <p>Facing its biggest student speech case in a half-century, the Supreme Court seemed to be looking for a narrow exit door on Wednesday.</p>,
#  <p>At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.</p>,
#  <p>The case has been billed as the most important student speech case since 1969. That landmark ruling came at the height of the Vietnam War. Mary Beth Tinker and four other students went to court after they were suspended for wearing black armbands to school to protest the war.</p>,
#  <p>By a vote of 7 to 2, the high court ruled at the time for the first time that kids do have First Amendment free speech rights at school, unless school officials reasonably forecast it will cause disruptions.</p>,
#  <p>Wednesday's case did not involve such serious speech. It was brought by Brandi Levy, a 14-year-old high school cheerleader, who failed to win a promotion from the junior varsity cheer team to the varsity.</p>,
#  <p>"I was really upset and frustrated at everything," Levy explained in an NPR interview. So, that weekend, she posted a photo of herself and a friend flipping the bird to the camera, with the caption "<em>F*** school F*** softball, F*** cheer, F*** everything."</em></p>,
#  <p>Brandi's post hit school like a small-town social media bomb; the school deemed the post disruptive to cheerleader morale and suspended her from the team for the rest of the year. The American Civil Liberties Union took her case to court, claiming that her free speech rights had been violated. And on Wednesday, the Supreme Court faced a question that did not exist in 1969: Can schools punish students for their online but off-campus speech?</p>,
#  <p>Justice Stephen Breyer got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment. "If swearing off-campus did [qualify], my goodness, every school in the country would be doing nothing but punishing," he said.</p>,
#  <p>Justice Sonia Sotomayor chimed in. "I'm told by my law clerks that ... among a certain large percentage of the population, how much you curse is a badge of honor," she said. "Kids basically talk to classmates, most of their exchanges have to do with their perceptions of the authoritarian nature of their teachers and others."</p>,
#  <p>Justice Brett Kavanaugh, who coaches his daughters' sports teams, seemed to understand Brandi's frustration, acknowledging that even NBA legend Michael Jordan had sore feelings more than 40 years after not making the varsity team in high school. As to this case, said Kavanaugh, "It didn't seem like the punishment was tailored to the offense. But how does that fit into the First Amendment Doctrine? Or does it at all?"</p>,
#  <p>The argument illustrated just how hard that question is. Siding with the Mahanoy school district in the case, the Justice Department argued that schools could regulate off-campus speech only if it is related to school matters and could cause a "substantial disruption."</p>,
#  <p>"That means really everything that mentions a school at all is school speech, right?" asked a skeptical Justice Elena Kagan.</p>,
#  <p>Deputy Solicitor General Malcolm Stewart tried to offer a nuanced distinction, but Kagan was having none of it. Cutting right to the question of which speech is punishable, she asked, "Can I give you a few hypotheticals, and you just tell me school speech or not school speech?"</p>,
#  <p>"The student emails his classmates the answer to the geometry homework every day after school?"</p>,
#  <p>"Student emails his classmates that they should all skip school tomorrow for an impromptu senior skip day?"</p>,
#  <p>"Student emails that they should refuse to do any work for English class until the teacher changes the syllabus to include more authors of color?"</p>,
#  <p>"Student tweets that there's pervasive homophobia at his school and that prospective gay students should stay away?"</p>,
#  <p>Each of these, conceded Stewart, would be considered school speech under the standard proposed by the Justice Department. In other words, all of these messages sent from off campus might well be punishable school speech.</p>,
#  <p>The ACLU's David Cole, representing Brandi Levy, said that once schools can discipline students for off-campus speech, that would dramatically expand the disciplinary reach of schools set out by the court in the <em>Tinker </em>case in 1969.</p>,
#  <p>"Expanding <em>Tinker</em> would transform a limited exception into a 24/7 rule that would upend the First Amendment's bedrock principle," argued Cole, "and would require students to effectively carry the schoolhouse on their backs in terms of speech rights everywhere they go."</p>,
#  <p>But, the justices wanted to know, what about cases of harassment and bullying? After all, some 47 states require enforcement of anti-bullying laws.</p>,
#  <p>Justice Kagan posited an off-campus website set up by high school boys to rank their female classmates appearance and sexual availability. All of the justices probed repeatedly for workable standard to adopt — a rule that would guide schools as to how to handle these tricky questions.</p>,
#  <p>Cole said student speech should be protected online. "Outside of school, the priority is not to give the school discretion to regulate kids' speech," he said.</p>,
#  <p>But the school district's lawyer, Lisa Blatt said that standard would be a "nightmare." It would, she said, mean "open season" on schools and produce "chaos" in the lower courts. "I guarantee you ... the courts are gonna freak out," she said.</p>,
#  <p>But from conservative to liberal, the justices were looking to do as little damage as possible. Admitted Justice Breyer, "I'm frightened to death of writing a standard."</p>,
#  <p class="left">Sponsor Message</p>,
#  <p class="right"><a href="/about-npr/186948703/corporate-sponsorship">Become an NPR sponsor</a></p>]

# %%
text = [tags.text.strip() for tags in p_tags]
text
# Out:
# ['Nina Totenberg',
#  'Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.\n                \n                \n                    \n                    Danna Singer/ACLU/AP\n                    \n                \nhide caption',
#  'Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.',
#  'Facing its biggest student speech case in a half-century, the Supreme Court seemed to be looking for a narrow exit door on Wednesday.',
#  'At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.',
#  'The case has been billed as the most important student speech case since 1969. That landmark ruling came at the height of the Vietnam War. Mary Beth Tinker and four other students went to court after they were suspended for wearing black armbands to school to protest the war.',
#  'By a vote of 7 to 2, the high court ruled at the time for the first time that kids do have First Amendment free speech rights at school, unless school officials reasonably forecast it will cause disruptions.',
#  "Wednesday's case did not involve such serious speech. It was brought by Brandi Levy, a 14-year-old high school cheerleader, who failed to win a promotion from the junior varsity cheer team to the varsity.",
#  '"I was really upset and frustrated at everything," Levy explained in an NPR interview. So, that weekend, she posted a photo of herself and a friend flipping the bird to the camera, with the caption "F*** school F*** softball, F*** cheer, F*** everything."',
#  "Brandi's post hit school like a small-town social media bomb; the school deemed the post disruptive to cheerleader morale and suspended her from the team for the rest of the year. The American Civil Liberties Union took her case to court, claiming that her free speech rights had been violated. And on Wednesday, the Supreme Court faced a question that did not exist in 1969: Can schools punish students for their online but off-campus speech?",
#  'Justice Stephen Breyer got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment. "If swearing off-campus did [qualify], my goodness, every school in the country would be doing nothing but punishing," he said.',
#  'Justice Sonia Sotomayor chimed in. "I\'m told by my law clerks that ... among a certain large percentage of the population, how much you curse is a badge of honor," she said. "Kids basically talk to classmates, most of their exchanges have to do with their perceptions of the authoritarian nature of their teachers and others."',
#  'Justice Brett Kavanaugh, who coaches his daughters\' sports teams, seemed to understand Brandi\'s frustration, acknowledging that even NBA legend Michael Jordan had sore feelings more than 40 years after not making the varsity team in high school. As to this case, said Kavanaugh, "It didn\'t seem like the punishment was tailored to the offense. But how does that fit into the First Amendment Doctrine? Or does it at all?"',
#  'The argument illustrated just how hard that question is. Siding with the Mahanoy school district in the case, the Justice Department argued that schools could regulate off-campus speech only if it is related to school matters and could cause a "substantial disruption."',
#  '"That means really everything that mentions a school at all is school speech, right?" asked a skeptical Justice Elena Kagan.',
#  'Deputy Solicitor General Malcolm Stewart tried to offer a nuanced distinction, but Kagan was having none of it. Cutting right to the question of which speech is punishable, she asked, "Can I give you a few hypotheticals, and you just tell me school speech or not school speech?"',
#  '"The student emails his classmates the answer to the geometry homework every day after school?"',
#  '"Student emails his classmates that they should all skip school tomorrow for an impromptu senior skip day?"',
#  '"Student emails that they should refuse to do any work for English class until the teacher changes the syllabus to include more authors of color?"',
#  '"Student tweets that there\'s pervasive homophobia at his school and that prospective gay students should stay away?"',
#  'Each of these, conceded Stewart, would be considered school speech under the standard proposed by the Justice Department. In other words, all of these messages sent from off campus might well be punishable school speech.',
#  "The ACLU's David Cole, representing Brandi Levy, said that once schools can discipline students for off-campus speech, that would dramatically expand the disciplinary reach of schools set out by the court in the Tinker case in 1969.",
#  '"Expanding Tinker would transform a limited exception into a 24/7 rule that would upend the First Amendment\'s bedrock principle," argued Cole, "and would require students to effectively carry the schoolhouse on their backs in terms of speech rights everywhere they go."',
#  'But, the justices wanted to know, what about cases of harassment and bullying? After all, some 47 states require enforcement of anti-bullying laws.',
#  'Justice Kagan posited an off-campus website set up by high school boys to rank their female classmates appearance and sexual availability. All of the justices probed repeatedly for workable standard to adopt — a rule that would guide schools as to how to handle these tricky questions.',
#  'Cole said student speech should be protected online. "Outside of school, the priority is not to give the school discretion to regulate kids\' speech," he said.',
#  'But the school district\'s lawyer, Lisa Blatt said that standard would be a "nightmare." It would, she said, mean "open season" on schools and produce "chaos" in the lower courts. "I guarantee you ... the courts are gonna freak out," she said.',
#  'But from conservative to liberal, the justices were looking to do as little damage as possible. Admitted Justice Breyer, "I\'m frightened to death of writing a standard."',
#  'Sponsor Message',
#  'Become an NPR sponsor']

# %%
sentence_list = [sentence for sentence in text if not '\n' in sentence]

# %%
sentence_list = [sentence for sentence in sentence_list if '.' in sentence]

# %%
article = ''.join(sentence_list)

# %%
summary = summarize(article)

# %%
summary
# Out:
# 'Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.Facing its biggest student speech case in a half-century, the Supreme Court seemed to be looking for a narrow exit door on Wednesday.At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.The case has been billed as the most important student speech case since 1969.\nThat landmark ruling came at the height of the Vietnam War. Mary Beth Tinker and four other students went to court after they were suspended for wearing black armbands to school to protest the war.By a vote of 7 to 2, the high court ruled at the time for the first time that kids do have First Amendment free speech rights at school, unless school officials reasonably forecast it will cause disruptions.Wednesday\'s case did not involve such serious speech.\nAnd on Wednesday, the Supreme Court faced a question that did not exist in 1969: Can schools punish students for their online but off-campus speech?Justice Stephen Breyer got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment.\nIn other words, all of these messages sent from off campus might well be punishable school speech.The ACLU\'s David Cole, representing Brandi Levy, said that once schools can discipline students for off-campus speech, that would dramatically expand the disciplinary reach of schools set out by the court in the Tinker case in 1969."Expanding Tinker would transform a limited exception into a 24/7 rule that would upend the First Amendment\'s bedrock principle," argued Cole, "and would require students to effectively carry the schoolhouse on their backs in terms of speech rights everywhere they go."But, the justices wanted to know, what about cases of harassment and bullying?'

# %% [markdown]
# # Tokenization

# %%
import spacy

# %% [markdown]
# ### Load the language model

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# <img src = 'nlp.png'>

# %%
doc = nlp(summary)

# %%
spacy.explain?

# %%
for token in doc:
    print(token.text, '--->', spacy.explain(token.text))
# Out:
# Brandi ---> None
# Levy ---> None
# wears ---> None
# her ---> None
# former ---> None
# cheerleading ---> None
# outfit ---> None
# as ---> None
# she ---> None
# looks ---> None
# at ---> None
# her ---> None
# mobile ---> None
# phone ---> None
# while ---> None
# sitting ---> None
# outside ---> None
# Mahanoy ---> None
# Area ---> None
# High ---> None
# School ---> None
# in ---> None
# Mahanoy ---> None
# City ---> None
# , ---> punctuation mark, comma
# Pa. ---> None
# , ---> punctuation mark, comma
# on ---> None
# April ---> None
# 4.Facing ---> None
# its ---> None
# biggest ---> None
# student ---> None
# speech ---> None
# case ---> case marking
# in ---> None
# a ---> None
# half ---> None
# - ---> None
# century ---> None
# , ---> punctuation mark, comma
# the ---> None
# Supreme ---> None
# Court ---> None
# seemed ---> None
# to ---> None
# be ---> None
# looking ---> None
# for ---> None
# a ---> None
# narrow ---> None
# exit ---> None
# door ---> None
# on ---> None
# Wednesday ---> None
# . ---> punctuation mark, sentence closer
# At ---> None
# issue ---> None
# was ---> None
# whether ---> None
# schools ---> None
# may ---> None
# punish ---> None
# students ---> None
# for ---> None
# speech ---> None
# that ---> None
# occurs ---> None
# online ---> None
# and ---> None
# off ---> None
# - ---> None
# campus ---> None
# but ---> None
# that ---> None
# may ---> None
# affect ---> None
# school ---> None
# order ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# case ---> case marking
# has ---> None
# been ---> None
# billed ---> None
# as ---> None
# the ---> None
# most ---> None
# important ---> None
# student ---> None
# speech ---> None
# case ---> case marking
# since ---> None
# 1969 ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# That ---> None
# landmark ---> None
# ruling ---> None
# came ---> None
# at ---> None
# the ---> None
# height ---> None
# of ---> None
# the ---> None
# Vietnam ---> None
# War ---> None
# . ---> punctuation mark, sentence closer
# Mary ---> None
# Beth ---> None
# Tinker ---> None
# and ---> None
# four ---> None
# other ---> None
# students ---> None
# went ---> None
# to ---> None
# court ---> None
# after ---> None
# they ---> None
# were ---> None
# suspended ---> None
# for ---> None
# wearing ---> None
# black ---> None
# armbands ---> None
# to ---> None
# school ---> None
# to ---> None
# protest ---> None
# the ---> None
# war ---> None
# . ---> punctuation mark, sentence closer
# By ---> None
# a ---> None
# vote ---> None
# of ---> None
# 7 ---> None
# to ---> None
# 2 ---> None
# , ---> punctuation mark, comma
# the ---> None
# high ---> None
# court ---> None
# ruled ---> None
# at ---> None
# the ---> None
# time ---> None
# for ---> None
# the ---> None
# first ---> None
# time ---> None
# that ---> None
# kids ---> None
# do ---> None
# have ---> None
# First ---> None
# Amendment ---> None
# free ---> None
# speech ---> None
# rights ---> None
# at ---> None
# school ---> None
# , ---> punctuation mark, comma
# unless ---> None
# school ---> None
# officials ---> None
# reasonably ---> None
# forecast ---> None
# it ---> None
# will ---> None
# cause ---> None
# disruptions ---> None
# . ---> punctuation mark, sentence closer
# Wednesday ---> None
# 's ---> None
# case ---> case marking
# did ---> None
# not ---> None
# involve ---> None
# such ---> None
# serious ---> None
# speech ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# And ---> None
# on ---> None
# Wednesday ---> None
# , ---> punctuation mark, comma
# the ---> None
# Supreme ---> None
# Court ---> None
# faced ---> None
# a ---> None
# question ---> None
# that ---> None
# did ---> None
# not ---> None
# exist ---> None
# in ---> None
# 1969 ---> None
# : ---> punctuation mark, colon or ellipsis
# Can ---> None
# schools ---> None
# punish ---> None
# students ---> None
# for ---> None
# their ---> None
# online ---> None
# but ---> None
# off ---> None
# - ---> None
# campus ---> None
# speech?Justice ---> None
# Stephen ---> None
# Breyer ---> None
# got ---> None
# to ---> None
# the ---> None
# heart ---> None
# of ---> None
# the ---> None
# matter ---> None
# quickly ---> None
# , ---> punctuation mark, comma
# wondering ---> None
# whether ---> None
# online ---> None
# swearing ---> None
# off ---> None
# - ---> None
# campus ---> None
# should ---> None
# even ---> None
# qualify ---> None
# for ---> None
# school ---> None
# punishment ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# In ---> None
# other ---> None
# words ---> None
# , ---> punctuation mark, comma
# all ---> None
# of ---> None
# these ---> None
# messages ---> None
# sent ---> None
# from ---> None
# off ---> None
# campus ---> None
# might ---> None
# well ---> None
# be ---> None
# punishable ---> None
# school ---> None
# speech ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# ACLU ---> None
# 's ---> None
# David ---> None
# Cole ---> None
# , ---> punctuation mark, comma
# representing ---> None
# Brandi ---> None
# Levy ---> None
# , ---> punctuation mark, comma
# said ---> None
# that ---> None
# once ---> None
# schools ---> None
# can ---> None
# discipline ---> None
# students ---> None
# for ---> None
# off ---> None
# - ---> None
# campus ---> None
# speech ---> None
# , ---> punctuation mark, comma
# that ---> None
# would ---> None
# dramatically ---> None
# expand ---> None
# the ---> None
# disciplinary ---> None
# reach ---> None
# of ---> None
# schools ---> None
# set ---> None
# out ---> None
# by ---> None
# the ---> None
# court ---> None
# in ---> None
# the ---> None
# Tinker ---> None
# case ---> case marking
# in ---> None
# 1969."Expanding ---> None
# Tinker ---> None
# would ---> None
# transform ---> None
# a ---> None
# limited ---> None
# exception ---> None
# into ---> None
# a ---> None
# 24/7 ---> None
# rule ---> None
# that ---> None
# would ---> None
# upend ---> None
# the ---> None
# First ---> None
# Amendment ---> None
# 's ---> None
# bedrock ---> None
# principle ---> None
# , ---> punctuation mark, comma
# " ---> None
# argued ---> None
# Cole ---> None
# , ---> punctuation mark, comma
# " ---> None
# and ---> None
# would ---> None
# require ---> None
# students ---> None
# to ---> None
# effectively ---> None
# carry ---> None
# the ---> None
# schoolhouse ---> None
# on ---> None
# their ---> None
# backs ---> None
# in ---> None
# terms ---> None
# of ---> None
# speech ---> None
# rights ---> None
# everywhere ---> None
# they ---> None
# go ---> None
# . ---> punctuation mark, sentence closer
# "But ---> None
# , ---> punctuation mark, comma
# the ---> None
# justices ---> None
# wanted ---> None
# to ---> None
# know ---> None
# , ---> punctuation mark, comma
# what ---> None
# about ---> None
# cases ---> None
# of ---> None
# harassment ---> None
# and ---> None
# bullying ---> None
# ? ---> None
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Brandi' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Levy' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'wears' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'her' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'former' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'cheerleading' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'outfit' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'as' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'she' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'looks' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'at' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'mobile' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'phone' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'while' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'sitting' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'outside' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Mahanoy' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Area' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'High' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'School' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'in' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'City' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Pa.' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'on' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'April' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term '4.Facing' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'its' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'biggest' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'student' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'speech' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'a' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'half' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term '-' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'century' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'the' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Supreme' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Court' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'seemed' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'to' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'be' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'looking' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'for' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'narrow' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'exit' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'door' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Wednesday' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'At' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'issue' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'was' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'whether' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'schools' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'may' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'punish' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'students' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'that' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'occurs' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'online' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'and' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'off' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'campus' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'but' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'affect' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'school' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'order' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'The' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'has' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'been' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'billed' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'most' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'important' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'since' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term '1969' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term '
# ' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'That' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'landmark' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'ruling' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'came' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'height' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'of' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Vietnam' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'War' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Mary' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Beth' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Tinker' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'four' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'other' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'went' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'court' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'after' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'they' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'were' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'suspended' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'wearing' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'black' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'armbands' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'protest' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'war' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'By' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'vote' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term '7' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term '2' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'high' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'ruled' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'time' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'first' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'kids' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'do' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'have' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'First' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Amendment' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'free' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'rights' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'unless' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'officials' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'reasonably' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'forecast' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'it' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'will' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'cause' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'disruptions' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term ''s' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'did' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'not' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'involve' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'such' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'serious' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'And' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'faced' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'question' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'exist' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Can' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'their' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# ...
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'from' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'might' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'well' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'punishable' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'ACLU' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'David' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'Cole' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'representing' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'said' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'once' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'can' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'discipline' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'would' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'dramatically' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'expand' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'disciplinary' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'reach' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'set' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'out' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'by' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term '1969."Expanding' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'transform' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'limited' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'exception' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'into' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term '24/7' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'rule' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'upend' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'bedrock' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'principle' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term '"' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'argued' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'require' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'effectively' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'carry' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'schoolhouse' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'backs' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'terms' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'everywhere' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'go' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term '"But' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'justices' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'wanted' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'know' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'what' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'about' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'cases' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'harassment' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'bullying' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term '?' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))

# %% [markdown]
# # POS tagging

# %%
for token in doc:
    print(token.text, '--->', token.pos_,'--->', spacy.explain(token.pos_))
# Out:
# Brandi ---> PROPN ---> proper noun
# Levy ---> PROPN ---> proper noun
# wears ---> VERB ---> verb
# her ---> PRON ---> pronoun
# former ---> ADJ ---> adjective
# cheerleading ---> NOUN ---> noun
# outfit ---> NOUN ---> noun
# as ---> SCONJ ---> subordinating conjunction
# she ---> PRON ---> pronoun
# looks ---> VERB ---> verb
# at ---> ADP ---> adposition
# her ---> PRON ---> pronoun
# mobile ---> ADJ ---> adjective
# phone ---> NOUN ---> noun
# while ---> SCONJ ---> subordinating conjunction
# sitting ---> VERB ---> verb
# outside ---> ADP ---> adposition
# Mahanoy ---> PROPN ---> proper noun
# Area ---> PROPN ---> proper noun
# High ---> PROPN ---> proper noun
# School ---> PROPN ---> proper noun
# in ---> ADP ---> adposition
# Mahanoy ---> PROPN ---> proper noun
# City ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# Pa. ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# on ---> ADP ---> adposition
# April ---> PROPN ---> proper noun
# 4.Facing ---> VERB ---> verb
# its ---> PRON ---> pronoun
# biggest ---> ADJ ---> adjective
# student ---> NOUN ---> noun
# speech ---> NOUN ---> noun
# case ---> NOUN ---> noun
# in ---> ADP ---> adposition
# a ---> DET ---> determiner
# half ---> ADJ ---> adjective
# - ---> PUNCT ---> punctuation
# century ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# Supreme ---> PROPN ---> proper noun
# Court ---> PROPN ---> proper noun
# seemed ---> VERB ---> verb
# to ---> PART ---> particle
# be ---> AUX ---> auxiliary
# looking ---> VERB ---> verb
# for ---> ADP ---> adposition
# a ---> DET ---> determiner
# narrow ---> ADJ ---> adjective
# exit ---> NOUN ---> noun
# door ---> NOUN ---> noun
# on ---> ADP ---> adposition
# Wednesday ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# At ---> ADP ---> adposition
# issue ---> NOUN ---> noun
# was ---> AUX ---> auxiliary
# whether ---> SCONJ ---> subordinating conjunction
# schools ---> NOUN ---> noun
# may ---> AUX ---> auxiliary
# punish ---> VERB ---> verb
# students ---> NOUN ---> noun
# for ---> ADP ---> adposition
# speech ---> NOUN ---> noun
# that ---> PRON ---> pronoun
# occurs ---> VERB ---> verb
# online ---> ADV ---> adverb
# and ---> CCONJ ---> coordinating conjunction
# off ---> ADP ---> adposition
# - ---> PUNCT ---> punctuation
# campus ---> NOUN ---> noun
# but ---> CCONJ ---> coordinating conjunction
# that ---> PRON ---> pronoun
# may ---> AUX ---> auxiliary
# affect ---> VERB ---> verb
# school ---> NOUN ---> noun
# order ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# case ---> NOUN ---> noun
# has ---> AUX ---> auxiliary
# been ---> AUX ---> auxiliary
# billed ---> VERB ---> verb
# as ---> ADP ---> adposition
# the ---> DET ---> determiner
# most ---> ADV ---> adverb
# important ---> ADJ ---> adjective
# student ---> NOUN ---> noun
# speech ---> NOUN ---> noun
# case ---> NOUN ---> noun
# since ---> SCONJ ---> subordinating conjunction
# 1969 ---> NUM ---> numeral
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# That ---> DET ---> determiner
# landmark ---> NOUN ---> noun
# ruling ---> NOUN ---> noun
# came ---> VERB ---> verb
# at ---> ADP ---> adposition
# the ---> DET ---> determiner
# height ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# Vietnam ---> PROPN ---> proper noun
# War ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# Mary ---> PROPN ---> proper noun
# Beth ---> PROPN ---> proper noun
# Tinker ---> PROPN ---> proper noun
# and ---> CCONJ ---> coordinating conjunction
# four ---> NUM ---> numeral
# other ---> ADJ ---> adjective
# students ---> NOUN ---> noun
# went ---> VERB ---> verb
# to ---> ADP ---> adposition
# court ---> NOUN ---> noun
# after ---> SCONJ ---> subordinating conjunction
# they ---> PRON ---> pronoun
# were ---> AUX ---> auxiliary
# suspended ---> VERB ---> verb
# for ---> ADP ---> adposition
# wearing ---> VERB ---> verb
# black ---> ADJ ---> adjective
# armbands ---> NOUN ---> noun
# to ---> ADP ---> adposition
# school ---> NOUN ---> noun
# to ---> PART ---> particle
# protest ---> VERB ---> verb
# the ---> DET ---> determiner
# war ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# By ---> ADP ---> adposition
# a ---> DET ---> determiner
# vote ---> NOUN ---> noun
# of ---> ADP ---> adposition
# 7 ---> NUM ---> numeral
# to ---> PART ---> particle
# 2 ---> NUM ---> numeral
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# high ---> ADJ ---> adjective
# court ---> NOUN ---> noun
# ruled ---> VERB ---> verb
# at ---> ADP ---> adposition
# the ---> DET ---> determiner
# time ---> NOUN ---> noun
# for ---> ADP ---> adposition
# the ---> DET ---> determiner
# first ---> ADJ ---> adjective
# time ---> NOUN ---> noun
# that ---> PRON ---> pronoun
# kids ---> NOUN ---> noun
# do ---> AUX ---> auxiliary
# have ---> VERB ---> verb
# First ---> PROPN ---> proper noun
# Amendment ---> PROPN ---> proper noun
# free ---> ADJ ---> adjective
# speech ---> NOUN ---> noun
# rights ---> NOUN ---> noun
# at ---> ADP ---> adposition
# school ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# unless ---> SCONJ ---> subordinating conjunction
# school ---> NOUN ---> noun
# officials ---> NOUN ---> noun
# reasonably ---> ADV ---> adverb
# forecast ---> VERB ---> verb
# it ---> PRON ---> pronoun
# will ---> AUX ---> auxiliary
# cause ---> VERB ---> verb
# disruptions ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Wednesday ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# case ---> NOUN ---> noun
# did ---> AUX ---> auxiliary
# not ---> PART ---> particle
# involve ---> VERB ---> verb
# such ---> ADJ ---> adjective
# serious ---> ADJ ---> adjective
# speech ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# And ---> CCONJ ---> coordinating conjunction
# on ---> ADP ---> adposition
# Wednesday ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# Supreme ---> PROPN ---> proper noun
# Court ---> PROPN ---> proper noun
# faced ---> VERB ---> verb
# a ---> DET ---> determiner
# question ---> NOUN ---> noun
# that ---> PRON ---> pronoun
# did ---> AUX ---> auxiliary
# not ---> PART ---> particle
# exist ---> VERB ---> verb
# in ---> ADP ---> adposition
# 1969 ---> NUM ---> numeral
# : ---> PUNCT ---> punctuation
# Can ---> AUX ---> auxiliary
# schools ---> NOUN ---> noun
# punish ---> VERB ---> verb
# students ---> NOUN ---> noun
# for ---> ADP ---> adposition
# their ---> PRON ---> pronoun
# online ---> NOUN ---> noun
# but ---> CCONJ ---> coordinating conjunction
# off ---> ADP ---> adposition
# - ---> PUNCT ---> punctuation
# campus ---> NOUN ---> noun
# speech?Justice ---> NOUN ---> noun
# Stephen ---> PROPN ---> proper noun
# Breyer ---> PROPN ---> proper noun
# got ---> VERB ---> verb
# to ---> ADP ---> adposition
# the ---> DET ---> determiner
# heart ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# matter ---> NOUN ---> noun
# quickly ---> ADV ---> adverb
# , ---> PUNCT ---> punctuation
# wondering ---> VERB ---> verb
# whether ---> SCONJ ---> subordinating conjunction
# online ---> ADV ---> adverb
# swearing ---> VERB ---> verb
# off ---> ADP ---> adposition
# - ---> PUNCT ---> punctuation
# campus ---> NOUN ---> noun
# should ---> AUX ---> auxiliary
# even ---> ADV ---> adverb
# qualify ---> VERB ---> verb
# for ---> ADP ---> adposition
# school ---> NOUN ---> noun
# punishment ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# In ---> ADP ---> adposition
# other ---> ADJ ---> adjective
# words ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# all ---> PRON ---> pronoun
# of ---> ADP ---> adposition
# these ---> DET ---> determiner
# messages ---> NOUN ---> noun
# sent ---> VERB ---> verb
# from ---> ADP ---> adposition
# off ---> ADP ---> adposition
# campus ---> NOUN ---> noun
# might ---> AUX ---> auxiliary
# well ---> ADV ---> adverb
# be ---> AUX ---> auxiliary
# punishable ---> ADJ ---> adjective
# school ---> NOUN ---> noun
# speech ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# ACLU ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# David ---> PROPN ---> proper noun
# Cole ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# representing ---> VERB ---> verb
# Brandi ---> PROPN ---> proper noun
# Levy ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# said ---> VERB ---> verb
# that ---> SCONJ ---> subordinating conjunction
# once ---> SCONJ ---> subordinating conjunction
# schools ---> NOUN ---> noun
# can ---> AUX ---> auxiliary
# discipline ---> VERB ---> verb
# students ---> NOUN ---> noun
# for ---> ADP ---> adposition
# off ---> ADP ---> adposition
# - ---> PUNCT ---> punctuation
# campus ---> NOUN ---> noun
# speech ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# that ---> PRON ---> pronoun
# would ---> AUX ---> auxiliary
# dramatically ---> ADV ---> adverb
# expand ---> VERB ---> verb
# the ---> DET ---> determiner
# disciplinary ---> ADJ ---> adjective
# reach ---> NOUN ---> noun
# of ---> ADP ---> adposition
# schools ---> NOUN ---> noun
# set ---> VERB ---> verb
# out ---> ADP ---> adposition
# by ---> ADP ---> adposition
# the ---> DET ---> determiner
# court ---> NOUN ---> noun
# in ---> ADP ---> adposition
# the ---> DET ---> determiner
# Tinker ---> PROPN ---> proper noun
# case ---> NOUN ---> noun
# in ---> ADP ---> adposition
# 1969."Expanding ---> VERB ---> verb
# Tinker ---> PROPN ---> proper noun
# would ---> AUX ---> auxiliary
# transform ---> VERB ---> verb
# a ---> DET ---> determiner
# limited ---> ADJ ---> adjective
# exception ---> NOUN ---> noun
# into ---> ADP ---> adposition
# a ---> DET ---> determiner
# 24/7 ---> NUM ---> numeral
# rule ---> NOUN ---> noun
# that ---> PRON ---> pronoun
# would ---> AUX ---> auxiliary
# upend ---> VERB ---> verb
# the ---> DET ---> determiner
# First ---> PROPN ---> proper noun
# Amendment ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# bedrock ---> NOUN ---> noun
# principle ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# " ---> PUNCT ---> punctuation
# argued ---> VERB ---> verb
# Cole ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# " ---> PUNCT ---> punctuation
# and ---> CCONJ ---> coordinating conjunction
# would ---> AUX ---> auxiliary
# require ---> VERB ---> verb
# students ---> NOUN ---> noun
# to ---> PART ---> particle
# effectively ---> ADV ---> adverb
# carry ---> VERB ---> verb
# the ---> DET ---> determiner
# schoolhouse ---> NOUN ---> noun
# on ---> ADP ---> adposition
# their ---> PRON ---> pronoun
# backs ---> NOUN ---> noun
# in ---> ADP ---> adposition
# terms ---> NOUN ---> noun
# of ---> ADP ---> adposition
# speech ---> NOUN ---> noun
# rights ---> NOUN ---> noun
# everywhere ---> ADV ---> adverb
# they ---> PRON ---> pronoun
# go ---> VERB ---> verb
# . ---> PUNCT ---> punctuation
# "But ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# justices ---> NOUN ---> noun
# wanted ---> VERB ---> verb
# to ---> PART ---> particle
# know ---> VERB ---> verb
# , ---> PUNCT ---> punctuation
# what ---> PRON ---> pronoun
# about ---> ADP ---> adposition
# cases ---> NOUN ---> noun
# of ---> ADP ---> adposition
# harassment ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# bullying ---> NOUN ---> noun
# ? ---> PUNCT ---> punctuation

# %% [markdown]
# # Dependency parsing

# %%
for token in doc:
    print(token.text, '--->', token.dep_, '--->', spacy.explain(token.dep_))
# Out:
# Brandi ---> compound ---> compound
# Levy ---> nsubj ---> nominal subject
# wears ---> ROOT ---> None
# her ---> poss ---> possession modifier
# former ---> amod ---> adjectival modifier
# cheerleading ---> compound ---> compound
# outfit ---> dobj ---> direct object
# as ---> mark ---> marker
# she ---> nsubj ---> nominal subject
# looks ---> advcl ---> adverbial clause modifier
# at ---> prep ---> prepositional modifier
# her ---> poss ---> possession modifier
# mobile ---> amod ---> adjectival modifier
# phone ---> pobj ---> object of preposition
# while ---> mark ---> marker
# sitting ---> advcl ---> adverbial clause modifier
# outside ---> prep ---> prepositional modifier
# Mahanoy ---> compound ---> compound
# Area ---> compound ---> compound
# High ---> compound ---> compound
# School ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# Mahanoy ---> compound ---> compound
# City ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# Pa. ---> appos ---> appositional modifier
# , ---> punct ---> punctuation
# on ---> prep ---> prepositional modifier
# April ---> nsubj ---> nominal subject
# 4.Facing ---> pcomp ---> complement of preposition
# its ---> poss ---> possession modifier
# biggest ---> amod ---> adjectival modifier
# student ---> compound ---> compound
# speech ---> compound ---> compound
# case ---> dobj ---> direct object
# in ---> prep ---> prepositional modifier
# a ---> det ---> determiner
# half ---> amod ---> adjectival modifier
# - ---> punct ---> punctuation
# century ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# the ---> det ---> determiner
# Supreme ---> compound ---> compound
# Court ---> nsubj ---> nominal subject
# seemed ---> ccomp ---> clausal complement
# to ---> aux ---> auxiliary
# be ---> aux ---> auxiliary
# looking ---> xcomp ---> open clausal complement
# for ---> prep ---> prepositional modifier
# a ---> det ---> determiner
# narrow ---> amod ---> adjectival modifier
# exit ---> compound ---> compound
# door ---> pobj ---> object of preposition
# on ---> prep ---> prepositional modifier
# Wednesday ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# At ---> prep ---> prepositional modifier
# issue ---> pobj ---> object of preposition
# was ---> ROOT ---> None
# whether ---> mark ---> marker
# schools ---> nsubj ---> nominal subject
# may ---> aux ---> auxiliary
# punish ---> ccomp ---> clausal complement
# students ---> dobj ---> direct object
# for ---> prep ---> prepositional modifier
# speech ---> pobj ---> object of preposition
# that ---> nsubj ---> nominal subject
# occurs ---> relcl ---> relative clause modifier
# online ---> advmod ---> adverbial modifier
# and ---> cc ---> coordinating conjunction
# off ---> conj ---> conjunct
# - ---> punct ---> punctuation
# campus ---> pobj ---> object of preposition
# but ---> cc ---> coordinating conjunction
# that ---> nsubj ---> nominal subject
# may ---> aux ---> auxiliary
# affect ---> conj ---> conjunct
# school ---> compound ---> compound
# order ---> dobj ---> direct object
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# case ---> nsubjpass ---> nominal subject (passive)
# has ---> aux ---> auxiliary
# been ---> auxpass ---> auxiliary (passive)
# billed ---> ROOT ---> None
# as ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# most ---> advmod ---> adverbial modifier
# important ---> amod ---> adjectival modifier
# student ---> compound ---> compound
# speech ---> compound ---> compound
# case ---> pobj ---> object of preposition
# since ---> prep ---> prepositional modifier
# 1969 ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
#
#  ---> dep ---> unclassified dependent
# That ---> det ---> determiner
# landmark ---> compound ---> compound
# ruling ---> nsubj ---> nominal subject
# came ---> ROOT ---> None
# at ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# height ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# Vietnam ---> compound ---> compound
# War ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# Mary ---> compound ---> compound
# Beth ---> compound ---> compound
# Tinker ---> nsubj ---> nominal subject
# and ---> cc ---> coordinating conjunction
# four ---> nummod ---> numeric modifier
# other ---> amod ---> adjectival modifier
# students ---> conj ---> conjunct
# went ---> ROOT ---> None
# to ---> prep ---> prepositional modifier
# court ---> pobj ---> object of preposition
# after ---> mark ---> marker
# they ---> nsubjpass ---> nominal subject (passive)
# were ---> auxpass ---> auxiliary (passive)
# suspended ---> advcl ---> adverbial clause modifier
# for ---> prep ---> prepositional modifier
# wearing ---> pcomp ---> complement of preposition
# black ---> amod ---> adjectival modifier
# armbands ---> dobj ---> direct object
# to ---> prep ---> prepositional modifier
# school ---> pobj ---> object of preposition
# to ---> aux ---> auxiliary
# protest ---> advcl ---> adverbial clause modifier
# the ---> det ---> determiner
# war ---> dobj ---> direct object
# . ---> punct ---> punctuation
# By ---> prep ---> prepositional modifier
# a ---> det ---> determiner
# vote ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# 7 ---> quantmod ---> modifier of quantifier
# to ---> quantmod ---> modifier of quantifier
# 2 ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# the ---> det ---> determiner
# high ---> amod ---> adjectival modifier
# court ---> nsubj ---> nominal subject
# ruled ---> ROOT ---> None
# at ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# time ---> pobj ---> object of preposition
# for ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# first ---> amod ---> adjectival modifier
# time ---> pobj ---> object of preposition
# that ---> advmod ---> adverbial modifier
# kids ---> nsubj ---> nominal subject
# do ---> aux ---> auxiliary
# have ---> relcl ---> relative clause modifier
# First ---> nmod ---> modifier of nominal
# Amendment ---> nmod ---> modifier of nominal
# free ---> amod ---> adjectival modifier
# speech ---> compound ---> compound
# rights ---> dobj ---> direct object
# at ---> prep ---> prepositional modifier
# school ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# unless ---> mark ---> marker
# school ---> compound ---> compound
# officials ---> nsubj ---> nominal subject
# reasonably ---> advmod ---> adverbial modifier
# forecast ---> advcl ---> adverbial clause modifier
# it ---> nsubj ---> nominal subject
# will ---> aux ---> auxiliary
# cause ---> ccomp ---> clausal complement
# disruptions ---> dobj ---> direct object
# . ---> punct ---> punctuation
# Wednesday ---> poss ---> possession modifier
# 's ---> case ---> case marking
# case ---> nsubj ---> nominal subject
# did ---> aux ---> auxiliary
# not ---> neg ---> negation modifier
# involve ---> ROOT ---> None
# such ---> amod ---> adjectival modifier
# serious ---> amod ---> adjectival modifier
# speech ---> dobj ---> direct object
# . ---> punct ---> punctuation
#
#  ---> dep ---> unclassified dependent
# And ---> cc ---> coordinating conjunction
# on ---> prep ---> prepositional modifier
# Wednesday ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# the ---> det ---> determiner
# Supreme ---> compound ---> compound
# Court ---> nsubj ---> nominal subject
# faced ---> ccomp ---> clausal complement
# a ---> det ---> determiner
# question ---> dobj ---> direct object
# that ---> nsubj ---> nominal subject
# did ---> aux ---> auxiliary
# not ---> neg ---> negation modifier
# exist ---> relcl ---> relative clause modifier
# in ---> prep ---> prepositional modifier
# 1969 ---> pobj ---> object of preposition
# : ---> punct ---> punctuation
# Can ---> aux ---> auxiliary
# schools ---> nsubj ---> nominal subject
# punish ---> ROOT ---> None
# students ---> dobj ---> direct object
# for ---> prep ---> prepositional modifier
# their ---> poss ---> possession modifier
# online ---> amod ---> adjectival modifier
# but ---> cc ---> coordinating conjunction
# off ---> conj ---> conjunct
# - ---> punct ---> punctuation
# campus ---> pobj ---> object of preposition
# speech?Justice ---> pobj ---> object of preposition
# Stephen ---> compound ---> compound
# Breyer ---> appos ---> appositional modifier
# got ---> conj ---> conjunct
# to ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# heart ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# matter ---> pobj ---> object of preposition
# quickly ---> advmod ---> adverbial modifier
# , ---> punct ---> punctuation
# wondering ---> advcl ---> adverbial clause modifier
# whether ---> mark ---> marker
# online ---> nsubj ---> nominal subject
# swearing ---> csubj ---> clausal subject
# off ---> prt ---> particle
# - ---> punct ---> punctuation
# campus ---> dobj ---> direct object
# should ---> aux ---> auxiliary
# even ---> advmod ---> adverbial modifier
# qualify ---> ccomp ---> clausal complement
# for ---> prep ---> prepositional modifier
# school ---> compound ---> compound
# punishment ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
#
#  ---> dep ---> unclassified dependent
# In ---> prep ---> prepositional modifier
# other ---> amod ---> adjectival modifier
# words ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# all ---> nsubj ---> nominal subject
# of ---> prep ---> prepositional modifier
# these ---> det ---> determiner
# messages ---> pobj ---> object of preposition
# sent ---> acl ---> clausal modifier of noun (adjectival clause)
# from ---> prep ---> prepositional modifier
# off ---> prep ---> prepositional modifier
# campus ---> pobj ---> object of preposition
# might ---> aux ---> auxiliary
# well ---> advmod ---> adverbial modifier
# be ---> ROOT ---> None
# punishable ---> amod ---> adjectival modifier
# school ---> compound ---> compound
# speech ---> attr ---> attribute
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# ACLU ---> poss ---> possession modifier
# 's ---> case ---> case marking
# David ---> compound ---> compound
# Cole ---> nsubj ---> nominal subject
# , ---> punct ---> punctuation
# representing ---> acl ---> clausal modifier of noun (adjectival clause)
# Brandi ---> compound ---> compound
# Levy ---> dobj ---> direct object
# , ---> punct ---> punctuation
# said ---> ccomp ---> clausal complement
# that ---> mark ---> marker
# once ---> mark ---> marker
# schools ---> nsubj ---> nominal subject
# can ---> aux ---> auxiliary
# discipline ---> advcl ---> adverbial clause modifier
# students ---> dobj ---> direct object
# for ---> prep ---> prepositional modifier
# off ---> nmod ---> modifier of nominal
# - ---> punct ---> punctuation
# campus ---> pobj ---> object of preposition
# speech ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# that ---> nsubj ---> nominal subject
# would ---> aux ---> auxiliary
# dramatically ---> advmod ---> adverbial modifier
# expand ---> ccomp ---> clausal complement
# the ---> det ---> determiner
# disciplinary ---> amod ---> adjectival modifier
# reach ---> nsubj ---> nominal subject
# of ---> prep ---> prepositional modifier
# schools ---> pobj ---> object of preposition
# set ---> acl ---> clausal modifier of noun (adjectival clause)
# out ---> prt ---> particle
# by ---> agent ---> agent
# the ---> det ---> determiner
# court ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# Tinker ---> compound ---> compound
# case ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# 1969."Expanding ---> pcomp ---> complement of preposition
# Tinker ---> dobj ---> direct object
# would ---> aux ---> auxiliary
# transform ---> ccomp ---> clausal complement
# a ---> det ---> determiner
# limited ---> amod ---> adjectival modifier
# exception ---> dobj ---> direct object
# into ---> prep ---> prepositional modifier
# a ---> det ---> determiner
# 24/7 ---> compound ---> compound
# rule ---> pobj ---> object of preposition
# that ---> nsubj ---> nominal subject
# would ---> aux ---> auxiliary
# upend ---> relcl ---> relative clause modifier
# the ---> det ---> determiner
# First ---> compound ---> compound
# Amendment ---> poss ---> possession modifier
# 's ---> case ---> case marking
# bedrock ---> compound ---> compound
# principle ---> dobj ---> direct object
# , ---> punct ---> punctuation
# " ---> punct ---> punctuation
# argued ---> ROOT ---> None
# Cole ---> nsubj ---> nominal subject
# , ---> punct ---> punctuation
# " ---> punct ---> punctuation
# and ---> cc ---> coordinating conjunction
# would ---> aux ---> auxiliary
# require ---> conj ---> conjunct
# students ---> dobj ---> direct object
# to ---> aux ---> auxiliary
# effectively ---> advmod ---> adverbial modifier
# carry ---> xcomp ---> open clausal complement
# the ---> det ---> determiner
# schoolhouse ---> dobj ---> direct object
# on ---> prep ---> prepositional modifier
# their ---> poss ---> possession modifier
# backs ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# terms ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# speech ---> compound ---> compound
# rights ---> pobj ---> object of preposition
# everywhere ---> advmod ---> adverbial modifier
# they ---> nsubj ---> nominal subject
# go ---> relcl ---> relative clause modifier
# . ---> punct ---> punctuation
# "But ---> npadvmod ---> noun phrase as adverbial modifier
# , ---> punct ---> punctuation
# the ---> det ---> determiner
# justices ---> nsubj ---> nominal subject
# wanted ---> ROOT ---> None
# to ---> aux ---> auxiliary
# know ---> xcomp ---> open clausal complement
# , ---> punct ---> punctuation
# what ---> dep ---> unclassified dependent
# about ---> prep ---> prepositional modifier
# cases ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# harassment ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# bullying ---> conj ---> conjunct
# ? ---> punct ---> punctuation
# C:\Users\hp\anaconda3\lib\site-packages\spacy\glossary.py:19: UserWarning: [W118] Term 'ROOT' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))

# %% [markdown]
# # Lemmatization

# %%
for token in doc:
    print(token.text, '--->', token.lemma_)
# Out:
# Brandi ---> Brandi
# Levy ---> Levy
# wears ---> wear
# her ---> her
# former ---> former
# cheerleading ---> cheerleading
# outfit ---> outfit
# as ---> as
# she ---> she
# looks ---> look
# at ---> at
# her ---> her
# mobile ---> mobile
# phone ---> phone
# while ---> while
# sitting ---> sit
# outside ---> outside
# Mahanoy ---> Mahanoy
# Area ---> Area
# High ---> High
# School ---> School
# in ---> in
# Mahanoy ---> Mahanoy
# City ---> City
# , ---> ,
# Pa. ---> Pa.
# , ---> ,
# on ---> on
# April ---> April
# 4.Facing ---> 4.face
# its ---> its
# biggest ---> big
# student ---> student
# speech ---> speech
# case ---> case
# in ---> in
# a ---> a
# half ---> half
# - ---> -
# century ---> century
# , ---> ,
# the ---> the
# Supreme ---> Supreme
# Court ---> Court
# seemed ---> seem
# to ---> to
# be ---> be
# looking ---> look
# for ---> for
# a ---> a
# narrow ---> narrow
# exit ---> exit
# door ---> door
# on ---> on
# Wednesday ---> Wednesday
# . ---> .
# At ---> at
# issue ---> issue
# was ---> be
# whether ---> whether
# schools ---> school
# may ---> may
# punish ---> punish
# students ---> student
# for ---> for
# speech ---> speech
# that ---> that
# occurs ---> occur
# online ---> online
# and ---> and
# off ---> off
# - ---> -
# campus ---> campus
# but ---> but
# that ---> that
# may ---> may
# affect ---> affect
# school ---> school
# order ---> order
# . ---> .
# The ---> the
# case ---> case
# has ---> have
# been ---> be
# billed ---> bill
# as ---> as
# the ---> the
# most ---> most
# important ---> important
# student ---> student
# speech ---> speech
# case ---> case
# since ---> since
# 1969 ---> 1969
# . ---> .
#
#  --->
#
# That ---> that
# landmark ---> landmark
# ruling ---> ruling
# came ---> come
# at ---> at
# the ---> the
# height ---> height
# of ---> of
# the ---> the
# Vietnam ---> Vietnam
# War ---> War
# . ---> .
# Mary ---> Mary
# Beth ---> Beth
# Tinker ---> Tinker
# and ---> and
# four ---> four
# other ---> other
# students ---> student
# went ---> go
# to ---> to
# court ---> court
# after ---> after
# they ---> they
# were ---> be
# suspended ---> suspend
# for ---> for
# wearing ---> wear
# black ---> black
# armbands ---> armband
# to ---> to
# school ---> school
# to ---> to
# protest ---> protest
# the ---> the
# war ---> war
# . ---> .
# By ---> by
# a ---> a
# vote ---> vote
# of ---> of
# 7 ---> 7
# to ---> to
# 2 ---> 2
# , ---> ,
# the ---> the
# high ---> high
# court ---> court
# ruled ---> rule
# at ---> at
# the ---> the
# time ---> time
# for ---> for
# the ---> the
# first ---> first
# time ---> time
# that ---> that
# kids ---> kid
# do ---> do
# have ---> have
# First ---> First
# Amendment ---> Amendment
# free ---> free
# speech ---> speech
# rights ---> right
# at ---> at
# school ---> school
# , ---> ,
# unless ---> unless
# school ---> school
# officials ---> official
# reasonably ---> reasonably
# forecast ---> forecast
# it ---> it
# will ---> will
# cause ---> cause
# disruptions ---> disruption
# . ---> .
# Wednesday ---> Wednesday
# 's ---> 's
# case ---> case
# did ---> do
# not ---> not
# involve ---> involve
# such ---> such
# serious ---> serious
# speech ---> speech
# . ---> .
#
#  --->
#
# And ---> and
# on ---> on
# Wednesday ---> Wednesday
# , ---> ,
# the ---> the
# Supreme ---> Supreme
# Court ---> Court
# faced ---> face
# a ---> a
# question ---> question
# that ---> that
# did ---> do
# not ---> not
# exist ---> exist
# in ---> in
# 1969 ---> 1969
# : ---> :
# Can ---> can
# schools ---> school
# punish ---> punish
# students ---> student
# for ---> for
# their ---> their
# online ---> online
# but ---> but
# off ---> off
# - ---> -
# campus ---> campus
# speech?Justice ---> speech?justice
# Stephen ---> Stephen
# Breyer ---> Breyer
# got ---> get
# to ---> to
# the ---> the
# heart ---> heart
# of ---> of
# the ---> the
# matter ---> matter
# quickly ---> quickly
# , ---> ,
# wondering ---> wonder
# whether ---> whether
# online ---> online
# swearing ---> swear
# off ---> off
# - ---> -
# campus ---> campus
# should ---> should
# even ---> even
# qualify ---> qualify
# for ---> for
# school ---> school
# punishment ---> punishment
# . ---> .
#
#  --->
#
# In ---> in
# other ---> other
# words ---> word
# , ---> ,
# all ---> all
# of ---> of
# these ---> these
# messages ---> message
# sent ---> send
# from ---> from
# off ---> off
# campus ---> campus
# might ---> might
# well ---> well
# be ---> be
# punishable ---> punishable
# school ---> school
# speech ---> speech
# . ---> .
# The ---> the
# ACLU ---> ACLU
# 's ---> 's
# David ---> David
# Cole ---> Cole
# , ---> ,
# representing ---> represent
# Brandi ---> Brandi
# Levy ---> Levy
# , ---> ,
# said ---> say
# that ---> that
# once ---> once
# schools ---> school
# can ---> can
# discipline ---> discipline
# students ---> student
# for ---> for
# off ---> off
# - ---> -
# campus ---> campus
# speech ---> speech
# , ---> ,
# that ---> that
# would ---> would
# dramatically ---> dramatically
# expand ---> expand
# the ---> the
# disciplinary ---> disciplinary
# reach ---> reach
# of ---> of
# schools ---> school
# set ---> set
# out ---> out
# by ---> by
# the ---> the
# court ---> court
# in ---> in
# the ---> the
# Tinker ---> Tinker
# case ---> case
# in ---> in
# 1969."Expanding ---> 1969."expande
# Tinker ---> Tinker
# would ---> would
# transform ---> transform
# a ---> a
# limited ---> limited
# exception ---> exception
# into ---> into
# a ---> a
# 24/7 ---> 24/7
# rule ---> rule
# that ---> that
# would ---> would
# upend ---> upend
# the ---> the
# First ---> First
# Amendment ---> Amendment
# 's ---> 's
# bedrock ---> bedrock
# principle ---> principle
# , ---> ,
# " ---> "
# argued ---> argue
# Cole ---> Cole
# , ---> ,
# " ---> "
# and ---> and
# would ---> would
# require ---> require
# students ---> student
# to ---> to
# effectively ---> effectively
# carry ---> carry
# the ---> the
# schoolhouse ---> schoolhouse
# on ---> on
# their ---> their
# backs ---> back
# in ---> in
# terms ---> term
# of ---> of
# speech ---> speech
# rights ---> right
# everywhere ---> everywhere
# they ---> they
# go ---> go
# . ---> .
# "But ---> "but
# , ---> ,
# the ---> the
# justices ---> justice
# wanted ---> want
# to ---> to
# know ---> know
# , ---> ,
# what ---> what
# about ---> about
# cases ---> case
# of ---> of
# harassment ---> harassment
# and ---> and
# bullying ---> bullying
# ? ---> ?

# %% [markdown]
# # Sentence boundary detection

# %%
sentences = list(doc.sents)

# %%
for sentence in sentences:
    print(sentence)
# Out:
# Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.Facing its biggest student speech case in a half-century, the Supreme Court seemed to be looking for a narrow exit door on Wednesday.
# At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.
# The case has been billed as the most important student speech case since 1969.
#
# That landmark ruling came at the height of the Vietnam War.
# Mary Beth Tinker and four other students went to court after they were suspended for wearing black armbands to school to protest the war.
# By a vote of 7 to 2, the high court ruled at the time for the first time that kids do have First Amendment free speech rights at school, unless school officials reasonably forecast it will cause disruptions.
# Wednesday's case did not involve such serious speech.
#
# And on Wednesday, the Supreme Court faced a question that did not exist in 1969: Can schools punish students for their online but off-campus speech?Justice Stephen Breyer got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment.
#
# In other words, all of these messages sent from off campus might well be punishable school speech.
# The ACLU's David Cole, representing Brandi Levy, said that once schools can discipline students for off-campus speech, that would dramatically expand the disciplinary reach of schools set out by the court in the Tinker case in 1969."Expanding Tinker would transform a limited exception into a 24/7 rule that would upend the First Amendment's bedrock principle," argued Cole, "and would require students to effectively carry the schoolhouse on their backs in terms of speech rights everywhere they go.
# "But, the justices wanted to know, what about cases of harassment and bullying?

# %% [markdown]
# # Named entity

# %%
for ent in doc.ents:
    print(ent.text, '---->', ent.label_, '---->', spacy.explain(ent.label_))
# Out:
# Brandi Levy ----> PERSON ----> People, including fictional
# Mahanoy Area High School in Mahanoy City ----> ORG ----> Companies, agencies, institutions, etc.
# Pa. ----> GPE ----> Countries, cities, states
# April 4.Facing ----> DATE ----> Absolute or relative dates or periods
# half-century ----> DATE ----> Absolute or relative dates or periods
# the Supreme Court ----> ORG ----> Companies, agencies, institutions, etc.
# Wednesday ----> DATE ----> Absolute or relative dates or periods
# 1969 ----> DATE ----> Absolute or relative dates or periods
# the Vietnam War ----> EVENT ----> Named hurricanes, battles, wars, sports events, etc.
# Mary Beth Tinker ----> PERSON ----> People, including fictional
# four ----> CARDINAL ----> Numerals that do not fall under another type
# 7 ----> CARDINAL ----> Numerals that do not fall under another type
# 2 ----> CARDINAL ----> Numerals that do not fall under another type
# first ----> ORDINAL ----> "first", "second", etc.
# First Amendment ----> LAW ----> Named documents made into laws.
# Wednesday ----> DATE ----> Absolute or relative dates or periods
# Wednesday ----> DATE ----> Absolute or relative dates or periods
# the Supreme Court ----> ORG ----> Companies, agencies, institutions, etc.
# 1969 ----> DATE ----> Absolute or relative dates or periods
# Stephen Breyer ----> PERSON ----> People, including fictional
# ACLU ----> ORG ----> Companies, agencies, institutions, etc.
# David Cole ----> PERSON ----> People, including fictional
# Brandi Levy ----> PERSON ----> People, including fictional
# Tinker ----> PERSON ----> People, including fictional
# Tinker ----> PERSON ----> People, including fictional
# 24/7 ----> CARDINAL ----> Numerals that do not fall under another type
# the First Amendment's ----> LAW ----> Named documents made into laws.
# Cole ----> PRODUCT ----> Objects, vehicles, foods, etc. (not services)

# %% [markdown]
# # Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brandi Levy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wears her former cheerleading outfit as she looks at her mobile phone while sitting outside
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mahanoy Area High School in Mahanoy City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pa.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 4.Facing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  its biggest student speech case in a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half-century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  seemed to be looking for a narrow exit door on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.The case has been billed as the most important student speech case since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1969
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br>That landmark ruling came at the height of
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Vietnam War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mary Beth Tinker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  other students went to court after they were suspended for wearing black armbands to school to protest the war.By a vote of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , the high court ruled at the time for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time that kids do have
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First Amendment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  free speech rights at school, unless school officials reasonably forecast it will cause disruptions.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's case did not involve such serious speech.</br>And on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  faced a question that did not exist in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1969
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : Can schools punish students for their online but off-campus speech?Justice
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stephen Breyer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment.</br>In other words, all of these messages sent from off campus might well be punishable school speech.The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ACLU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     David Cole
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , represent

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9016b1dd2fac45b78b7888a7f83976d6-0" class="displacy" width="57800" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Brandi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Levy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">wears</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">former</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">cheerleading</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">outfit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">looks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">mobile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">phone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">while</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">sitting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">outside</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Mahanoy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Area</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">High</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">School</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Mahanoy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">City,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Pa.,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">April</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">4.Facing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">biggest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">student</tspan>
#     <tspan class="displacy-tag" dy="

# %% [markdown]
# # Putting it all together

# %%
lis = []

# %%
for token in doc:
    dic = {}
    dic['Token'] = token.text
    dic['POS'] = token.pos_
    dic['Tags'] = token.tag_
    dic['Dep'] = token.dep_
    dic['Explanation'] = spacy.explain(token.tag_)
    lis.append(dic)

# %%
import pandas as pd

# %%
data = pd.DataFrame(lis)

# %%
data
# Out:
#           Token    POS  Tags       Dep  \
# 0        Brandi  PROPN   NNP  compound
# 1          Levy  PROPN   NNP     nsubj
# 2         wears   VERB   VBZ      ROOT
# 3           her   PRON  PRP$      poss
# 4        former    ADJ    JJ      amod
# ..          ...    ...   ...       ...
# 359          of    ADP    IN      prep
# 360  harassment   NOUN    NN      pobj
# 361         and  CCONJ    CC        cc
# 362    bullying   NOUN    NN      conj
# 363           ?  PUNCT     .     punct
#
#                                            Explanation
# 0                                noun, proper singular
# 1                                noun, proper singular
# 2                    verb, 3rd person singular present
# 3                                  pronoun, possessive
# 4    adjective (English), other noun-modifier (Chin...
# ..                                                 ...
# 359          conjunction, subordinating or preposition
# 360                             noun, singular or mass
# 361                          conjunction, coordinating
# 362                             noun, singular or mass
# 363                  punctuation mark, sentence closer
#
# [364 rows x 5 columns]

# %%
l = []
for ent in doc.ents:
    d = {}
    d['entities'] = ent.text
    d['labels'] = ent.label_
    d['Explanation'] = spacy.explain(ent.label_)
    l.append(d)

# %%
entities = pd.DataFrame(l)

# %%
entities
# Out:
#                                     entities    labels  \
# 0                                Brandi Levy    PERSON
# 1   Mahanoy Area High School in Mahanoy City       ORG
# 2                                        Pa.       GPE
# 3                             April 4.Facing      DATE
# 4                               half-century      DATE
# 5                          the Supreme Court       ORG
# 6                                  Wednesday      DATE
# 7                                       1969      DATE
# 8                            the Vietnam War     EVENT
# 9                           Mary Beth Tinker    PERSON
# 10                                      four  CARDINAL
# 11                                         7  CARDINAL
# 12                                         2  CARDINAL
# 13                                     first   ORDINAL
# 14                           First Amendment       LAW
# 15                                 Wednesday      DATE
# 16                                 Wednesday      DATE
# 17                         the Supreme Court       ORG
# 18                                      1969      DATE
# 19                            Stephen Breyer    PERSON
# 20                                      ACLU       ORG
# 21                                David Cole    PERSON
# 22                               Brandi Levy    PERSON
# 23                                    Tinker    PERSON
# 24                                    Tinker    PERSON
# 25                                      24/7  CARDINAL
# 26                     the First Amendment's       LAW
# 27                                      Cole   PRODUCT
#
#                                           Explanation
# 0                         People, including fictional
# 1             Companies, agencies, institutions, etc.
# 2                           Countries, cities, states
# 3               Absolute or relative dates or periods
# 4               Absolute or relative dates or periods
# 5             Companies, agencies, institutions, etc.
# 6               Absolute or relative dates or periods
# 7               Absolute or relative dates or periods
# 8   Named hurricanes, battles, wars, sports events...
# 9                         People, including fictional
# 10       Numerals that do not fall under another type
# 11       Numerals that do not fall under another type
# 12       Numerals that do not fall under another type
# 13                            "first", "second", etc.
# 14                    Named documents made into laws.
# 15              Absolute or relative dates or periods
# 16              Absolute or relative dates or periods
# 17            Companies, agencies, institutions, etc.
# 18              Absolute or relative dates or periods
# 19                        People, including fictional
# 20            Companies, agencies, institutions, etc.
# 21                        People, including fictional
# 22                        People, including fictional
# 23                        People, including fictional
# 24                        People, including fictional
# 25       Numerals that do not fall under another type
# 26                    Named documents made into laws.
# 27      Objects, vehicles, foods, etc. (not services)

# %%
import docx

# %%
doc = docx.Document()

# %%
doc.add_heading(header)

# %%
doc.add_picture('img.jpg')

# %%
doc.add_paragraph(summary)

# %%
doc.save('last1.docx')

# %%
doc.add_paragraph(date)

# %%
doc.a
